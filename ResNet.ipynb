# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import torch.nn.functional as F
import torch.optim as optim
# import torch.utils.data
from torch.utils.data import TensorDataset, Dataset, DataLoader
from torchvision import datasets

from torchsummary import summary

import cv2
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %% [markdown]
# ## Data load, preprocess

# %%
data = datasets.CIFAR10(root='data', train=True, download=True)

means = data.data.mean(axis=(0, 1, 2)) / 255
stds = data.data.std(axis=(0, 1, 2)) / 255
print(means)
print(stds)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data/cifar-10-python.tar.gz to data
# [0.49139968 0.48215841 0.44653091]
# [0.24703223 0.24348513 0.26158784]

# %%
transforms_train = transforms.Compose([
                            transforms.RandomRotation(5),
                            transforms.RandomHorizontalFlip(0.5),
                            transforms.RandomCrop(32, padding=2),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=means, std=stds)
                        ])

transforms_test = transforms.Compose([
                            transforms.ToTensor(),
                            transforms.Normalize(mean=means, std=stds)
                        ])

# %%
train_data = datasets.CIFAR10(root='data', train=True, download=True, 
                              transform=transforms_train)

test_data = datasets.CIFAR10(root='data', train=False, download=True, 
                              transform=transforms_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
el_num = int(len(train_data) * 0.8)
train_data, val_data = torch.utils.data.random_split(train_data, [el_num, len(train_data) - el_num])

# %%
import copy
val_data = copy.deepcopy(val_data)
val_data.dataset.transform = transforms_test

# %%
print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 40000
# 10000
# 10000

# %%
def inv_normalize_image(image, means, stds):
    image = transforms.Normalize(
            mean=-means/stds,
            std=1/stds
        )(image)
    return image

# %%
def plot_images(images, labels):
    n = int(np.sqrt(len(images)))

    fig, axis = plt.subplots(n, n, figsize=(10, 10))
    plt.subplots_adjust(top=0.95, hspace=0.4)

    for idx, im in enumerate(images):
        i = idx % n
        j = idx // n
        img = inv_normalize_image(im, means, stds)
        img = img.to('cpu').permute(1, 2, 0).numpy()
        img[img>1] = 1
        img[img<0] = 0

        axis[i][j].imshow(img)
        axis[i][j].set_title(labels[idx])
        axis[i][j].set_xticklabels([])
        axis[i][j].set_yticklabels([])
        axis[i][j].set_aspect('equal')

images, labels = zip(*[(im, lbl) for im, lbl in 
                       [train_data[i] for i in range(64)]])
classes = test_data.classes
labels = [classes[i] for i in labels]
plot_images(images, labels)

# %%
train_loader = DataLoader(train_data, shuffle=True, batch_size=64)
val_loader = DataLoader(val_data, shuffle=True, batch_size=64)
test_loader = DataLoader(test_data, shuffle=True, batch_size=64)

# %% [markdown]
# ## Train Functions

# %%
import time

def train(model, optimizer, train_data, val_data, test_data, num_epochs, device='cuda'):
    history = {}
    history['train_loss'] = []
    history['train_acc'] = []
    history['val_loss'] = []
    history['val_acc'] = []

    history['test_loss'] = 0
    history['test_acc'] = 0

    start_time = time.time()

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))

        epoch_time = time.time()

        tr_loss, tr_acc = train_step(model, optimizer, train_data, epoch+1, num_epochs, device)
        history['train_loss'].append(tr_loss)
        history['train_acc'].append(tr_acc)

        vl_loss, vl_acc = validate(model, optimizer, val_data, epoch+1, num_epochs, device)
        history['val_loss'].append(vl_loss)
        history['val_acc'].append(vl_acc)

        epoch_time = time.time() - epoch_time
        print('Epoch completed in {:.0f}m {:.0f}s'.format(
            epoch_time // 60, epoch_time % 60))
        print('#' * 20)
        print()

    ts_loss, ts_acc = test(model, optimizer, test_data, epoch+1, num_epochs, device)
    history['test_loss'] = ts_loss
    history['test_acc'] = ts_acc

    start_time = time.time() - start_time
    print('Model trained in {:.0f}m {:.0f}s'.format(
    start_time // 60, start_time % 60))

    return history

# %%
def train_step(model, optimizer, train_data, epoch, epochs, device='cuda'):
    losses = []
    accs = []

    max_size = len(train_data.dataset)
    idx = 0
    idx_step = 0.0

    model.train()

    for data, target in train_data:
        idx += len(data)

        model.zero_grad()

        data = data.to(device)
        target = target.to(device)

        pred, _ = model(data)
        loss = loss_fn(pred, target)

        loss.backward()
        optimizer.step()

        losses.append(loss.item())
        pred = torch.argmax(pred, dim=1)
        # target = torch.argmax(target, dim=1)
        accs.append(torch.sum(pred == target).item() / len(data))

        if (max_size * idx_step) <= idx:

            l = sum(losses) / len(losses)
            a = sum(accs) / len(accs)

            print_status('Train', epoch, epochs, l, a * 100, max_size * idx_step, max_size)

            idx_step += 0.2

    loss = sum(losses) / len(losses)
    acc = sum(accs) / len(accs)

    return loss, acc

# %%
def validate(model, optimizer, val_data, epoch, epochs, device='cuda'):
    losses = []
    accs = []

    model.eval()

    with torch.no_grad():
        for idx, (data, target) in enumerate(val_data):
            data = data.to(device)
            target = target.to(device)

            pred, _ = model(data)
            loss = loss_fn(pred, target)

            losses.append(loss.item())
            pred = torch.argmax(pred, dim=1)
            # target = torch.argmax(target, dim=1)
            accs.append(torch.sum(pred == target).item() / len(data))

    loss = sum(losses) / len(losses)
    acc = sum(accs) / len(accs)

    print_status('Validate', epoch, epochs, loss, acc * 100)

    return loss, acc

# %%
def test(model, optimizer, test_data, epoch, epochs, device='cuda'):
    losses = []
    accs = []

    model.eval()

    with torch.no_grad():
        for idx, (data, target) in enumerate(test_data):
            data = data.to(device)
            target = target.to(device)

            pred, _ = model(data)
            loss = loss_fn(pred, target)

            losses.append(loss.item())
            pred = torch.argmax(pred, dim=1)
            # target = torch.argmax(target, dim=1)
            accs.append(torch.sum(pred == target).item() / len(data))

    loss = sum(losses) / len(losses)
    acc = sum(accs) / len(accs)

    print_status('Test', epoch, epochs, loss, acc * 100)

    return loss, acc

# %%
def print_status(mode, epoch, epochs, loss, acc, idx = 0, max_idx = 0):
    s = mode
    if mode == "Validate":
        s += '\t({:2d}/{:2d})'.format(epoch, epochs)
    elif mode == "Train":
        s += '\t({:2d}/{:2d}) {:4.0f}/{:4d} ({:2.2f}%)'.format(
            epoch, epochs, idx, max_idx, idx/max_idx*100
        )

    s += ' loss: {:.3f}'.format(loss)
    s += ' accuracy: {:.3f}'.format(acc)

    print(s)

# %% [markdown]
# ## Model

# %%
class ResNet(nn.Module):
    def __init__(self, block, n_blocks, channels, out):
        super().__init__()

        self.in_c = channels[0]

        self.conv1 = nn.Conv2d(3, channels[0], kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.norm1 = nn.BatchNorm2d(channels[0])
        self.relu = nn.ReLU(inplace=True)

        self.res1 = self.gen_layer(block, n_blocks[0], channels[0])
        self.res2 = self.gen_layer(block, n_blocks[1], channels[1], stride=2)
        self.res3 = self.gen_layer(block, n_blocks[2], channels[2], stride=2)

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(channels[-1], out)


    def gen_layer(self, block, n_blocks, channels, stride=1):
        layers = []

        downsample = False
        if self.in_c != channels:
            downsample = True

        layers.append(block(self.in_c, channels, stride, downsample))
        
        for _ in range(n_blocks-1):
            layers.append(block(channels, channels))

        self.in_c = channels

        return nn.Sequential(*layers)
        

    def forward(self, x):
        x = self.conv1(x)
        x = self.norm1(x)
        x = self.relu(x)

        x = self.res1(x)
        x = self.res2(x)
        x = self.res3(x)

        x = self.avgpool(x)
        h = x.view(x.shape[0], -1)
        x = self.fc(h)

        return x, h

# %%
class Identity(nn.Module):
    def __init__(self, f):
        super().__init__()
        self.f = f

    def forward(self, x):
        return self.f(x)

# %%
class Block(nn.Module):
    def __init__(self, in_c, out_c, stride=1, downsample=False):
        super().__init__()

        self.conv1 = nn.Conv2d(in_c, out_c, kernel_size=3, stride=stride,
                               padding=1, bias=False)
        self.norm1 = nn.BatchNorm2d(out_c)

        self.conv2 = nn.Conv2d(out_c, out_c, kernel_size=3, stride=1,
                               padding=1, bias=False)
        self.norm2 = nn.BatchNorm2d(out_c)

        self.relu = nn.ReLU(inplace=True)

        self.downsample = None
        if downsample:
            identity_f = lambda x : F.pad(x[:, :, ::2, ::2],
                                          [0, 0, 0, 0, in_c//2, in_c//2])
            self.downsample = Identity(identity_f)

    def forward(self, x):
        x_pre = x

        x = self.conv1(x)
        x = self.norm1(x)
        x = self.relu(x)

        x = self.conv2(x)
        x = self.norm2(x)

        if self.downsample is not None:
            x_pre = self.downsample(x_pre)

        x += x_pre
        x = self.relu(x)

        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
resnet = ResNet(Block, [3, 3, 3], [16, 32, 64], 10).to(device)

# %%
summary(resnet, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             432
#        BatchNorm2d-2           [-1, 16, 32, 32]              32
#               ReLU-3           [-1, 16, 32, 32]               0
#             Conv2d-4           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-5           [-1, 16, 32, 32]              32
#               ReLU-6           [-1, 16, 32, 32]               0
#             Conv2d-7           [-1, 16, 32, 32]           2,304
#        BatchNorm2d-8           [-1, 16, 32, 32]              32
#               ReLU-9           [-1, 16, 32, 32]               0
#             Block-10           [-1, 16, 32, 32]               0
#            Conv2d-11           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-12           [-1, 16, 32, 32]              32
#              ReLU-13           [-1, 16, 32, 32]               0
#            Conv2d-14           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-15           [-1, 16, 32, 32]              32
#              ReLU-16           [-1, 16, 32, 32]               0
#             Block-17           [-1, 16, 32, 32]               0
#            Conv2d-18           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-19           [-1, 16, 32, 32]              32
#              ReLU-20           [-1, 16, 32, 32]               0
#            Conv2d-21           [-1, 16, 32, 32]           2,304
#       BatchNorm2d-22           [-1, 16, 32, 32]              32
#              ReLU-23           [-1, 16, 32, 32]               0
#             Block-24           [-1, 16, 32, 32]               0
#            Conv2d-25           [-1, 32, 16, 16]           4,608
#       BatchNorm2d-26           [-1, 32, 16, 16]              64
#              ReLU-27           [-1, 32, 16, 16]               0
#            Conv2d-28           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-29           [-1, 32, 16, 16]              64
#          Identity-30           [-1, 32, 16, 16]               0
#              ReLU-31           [-1, 32, 16, 16]               0
#             Block-32           [-1, 32, 16, 16]               0
#            Conv2d-33           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-34           [-1, 32, 16, 16]              64
#              ReLU-35           [-1, 32, 16, 16]               0
#            Conv2d-36           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-37           [-1, 32, 16, 16]              64
#              ReLU-38           [-1, 32, 16, 16]               0
#             Block-39           [-1, 32, 16, 16]               0
#            Conv2d-40           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-41           [-1, 32, 16, 16]              64
#              ReLU-42           [-1, 32, 16, 16]               0
#            Conv2d-43           [-1, 32, 16, 16]           9,216
#       BatchNorm2d-44           [-1, 32, 16, 16]              64
#              ReLU-45           [-1, 32, 16, 16]               0
#             Block-46           [-1, 32, 16, 16]               0
#            Conv2d-47             [-1, 64, 8, 8]          18,432
#       BatchNorm2d-48             [-1, 64, 8, 8]             128
#              ReLU-49             [-1, 64, 8, 8]               0
#            Conv2d-50             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-51             [-1, 64, 8, 8]             128
#          Identity-52             [-1, 64, 8, 8]               0
#              ReLU-53             [-1, 64, 8, 8]               0
#             Block-54             [-1, 64, 8, 8]               0
#            Conv2d-55             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-56             [-1, 64, 8, 8]             128
#              ReLU-57             [-1, 64, 8, 8]               0
#            Conv2d-58             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-59             [-1, 64, 8, 8]             128
#              ReLU-60             [-1, 64, 8, 8]               0
#             Block-61             [-1, 64, 8, 8]               0
#            Conv2d-62             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-63             [-1, 64, 8, 8]             128
#              ReLU-64             [-1, 64, 8, 8]               0
#            Conv2d-65             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-66             [-1, 64, 8, 8]             128
#              ReLU-67             [-1, 64, 8, 8]               0
#             Block-68             [-1, 64, 8, 8]               0
# AdaptiveAvgPool2d-69             [-1, 64, 1, 1]               0
#            Linear-70                   [-1, 10]             650
# ================================================================
# Total params: 269,722
# Trainable params: 269,722
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 5.06
# Params size (MB): 1.03
# Estimated Total Size (MB): 6.10
# ----------------------------------------------------------------

# %%
train_loader = DataLoader(train_data, shuffle=True, batch_size=256)
val_loader = DataLoader(val_data, shuffle=True, batch_size=256)
test_loader = DataLoader(test_data, shuffle=True, batch_size=256)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
loss_fn = nn.CrossEntropyLoss()
resnet = ResNet(Block, [3, 3, 3], [16, 32, 64], 10).to(device)
optimizer = optim.Adam(resnet.parameters(), lr=0.001)

# %%
history = train(resnet, optimizer, train_loader, val_loader, test_loader, 25, device=device)
# Out:
# Epoch 1/25
# Train	( 1/25)    0/40000 (0.00%) loss: 2.558 accuracy: 11.328
# Train	( 1/25) 8000/40000 (20.00%) loss: 1.913 accuracy: 28.955
# Train	( 1/25) 16000/40000 (40.00%) loss: 1.746 accuracy: 35.088
# Train	( 1/25) 24000/40000 (60.00%) loss: 1.648 accuracy: 39.133
# Train	( 1/25) 32000/40000 (80.00%) loss: 1.569 accuracy: 42.244
# Train	( 1/25) 40000/40000 (100.00%) loss: 1.508 accuracy: 44.713
# Validate	( 1/25) loss: 1.376 accuracy: 50.762
# Epoch completed in 0m 52s
# ####################
#
# Epoch 2/25
# Train	( 2/25)    0/40000 (0.00%) loss: 1.215 accuracy: 57.031
# Train	( 2/25) 8000/40000 (20.00%) loss: 1.217 accuracy: 56.140
# Train	( 2/25) 16000/40000 (40.00%) loss: 1.181 accuracy: 57.645
# Train	( 2/25) 24000/40000 (60.00%) loss: 1.157 accuracy: 58.457
# Train	( 2/25) 32000/40000 (80.00%) loss: 1.136 accuracy: 59.278
# Train	( 2/25) 40000/40000 (100.00%) loss: 1.109 accuracy: 60.129
# Validate	( 2/25) loss: 1.182 accuracy: 58.994
# Epoch completed in 0m 51s
# ####################
#
# Epoch 3/25
# Train	( 3/25)    0/40000 (0.00%) loss: 0.984 accuracy: 65.625
# Train	( 3/25) 8000/40000 (20.00%) loss: 1.010 accuracy: 63.757
# Train	( 3/25) 16000/40000 (40.00%) loss: 0.992 accuracy: 64.813
# Train	( 3/25) 24000/40000 (60.00%) loss: 0.968 accuracy: 65.687
# Train	( 3/25) 32000/40000 (80.00%) loss: 0.957 accuracy: 65.856
# Train	( 3/25) 40000/40000 (100.00%) loss: 0.946 accuracy: 66.356
# Validate	( 3/25) loss: 1.087 accuracy: 62.275
# Train	(23/25) 16000/40000 (40.00%) loss: 0.362 accuracy: 87.574
# Train	(23/25) 24000/40000 (60.00%) loss: 0.366 accuracy: 87.321
# Train	(23/25) 32000/40000 (80.00%) loss: 0.371 accuracy: 87.128
# Train	(23/25) 40000/40000 (100.00%) loss: 0.369 accuracy: 87.149
# Validate	(23/25) loss: 0.548 accuracy: 82.002
# Epoch completed in 0m 51s
# ####################
#
# Epoch 24/25
# Train	(24/25)    0/40000 (0.00%) loss: 0.325 accuracy: 87.109
# Train	(24/25) 8000/40000 (20.00%) loss: 0.355 accuracy: 87.463
# Train	(24/25) 16000/40000 (40.00%) loss: 0.355 accuracy: 87.351
# Train	(24/25) 24000/40000 (60.00%) loss: 0.355 accuracy: 87.355
# Train	(24/25) 32000/40000 (80.00%) loss: 0.355 accuracy: 87.400
# Train	(24/25) 40000/40000 (100.00%) loss: 0.356 accuracy: 87.381
# Validate	(24/25) loss: 0.487 accuracy: 84.502
# Epoch completed in 0m 52s
# ####################
#
# Epoch 25/25
# Train	(25/25)    0/40000 (0.00%) loss: 0.248 accuracy: 92.188
# Train	(25/25) 8000/40000 (20.00%) loss: 0.339 accuracy: 88.184
# Train	(25/25) 16000/40000 (40.00%) loss: 0.338 accuracy: 88.083
# Train	(25/25) 24000/40000 (60.00%) loss: 0.344 accuracy: 87.965
# Train	(25/25) 32000/40000 (80.00%) loss: 0.344 accuracy: 87.869
# Train	(25/25) 40000/40000 (100.00%) loss: 0.346 accuracy: 87.741
# Validate	(25/25) loss: 0.507 accuracy: 83.037
# Epoch completed in 0m 52s
# ####################
#
# Test loss: 0.528 accuracy: 82.314
# Model trained in 21m 33s

# %% [markdown]
# ## Visualization Functions

# %%
def visualize_loss(history):
    ind = list(range(len(history['train_loss'])))
    plt.plot(ind, history['train_loss'], label='line1')
    plt.plot(ind, history['val_loss'], label='line2')
    plt.scatter(ind[-1], history['test_loss'], label='point1')

    plt.legend([
        'train_loss',
        'val_loss',
        'test_loss'
    ])

    plt.ylabel('Loss')
    plt.title('Losses plot')
    plt.show()

# %%
def visualize_acc(history):
    ind = list(range(len(history['train_acc'])))
    plt.plot(ind, history['train_acc'], label='line1')
    plt.plot(ind, history['val_acc'], label='line2')
    plt.scatter(ind[-1], history['test_acc'], label='point1')

    plt.legend([
        'train_acc',
        'val_acc',
        'test_acc'
    ])

    plt.ylabel('Accuracy')
    plt.title('Accuracy plot')
    plt.show()

# %%
def get_predictions(model, data_loader, device):
    model.eval()
    images = []
    labels = []

    with torch.no_grad():
        for (data, target) in data_loader:
            data = data.to(device)
            pred, _ = model(data)
            pred = torch.argmax(pred, dim=1)
            classes = test_data.classes
            pred = [classes[i] for i in pred]

            images.append(data.cpu())
            labels += pred
            break

    images = torch.cat(images, dim=0)
    return images, labels

# %%
visualize_acc(history)

# %%
visualize_loss(history)

# %%
images, labels = get_predictions(resnet, test_loader, device)
plot_images(images[:64], labels[:64])
